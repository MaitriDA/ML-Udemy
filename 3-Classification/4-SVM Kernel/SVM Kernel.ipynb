# %% [markdown]
# # SVM Kernel

# %% [markdown]
# In SVM we generally seperate the two regions using lines. But how do we seperate the below data points, it is not possible to divide them using a horizontal, vertical of slant line. In this case the data is not linearly seperable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In 1 dimension the seperation is using a sinle do1.<br>
# In 2 dimension the seperation is using a line.<br>
# In 3 dimension the seperation is using a place.

# %% [markdown]
# We seperate the dataset that are not linearly seperable by increasing the dimension and then apply linear seperation.

# %% [markdown]
# ## 1D - 1 Dimension

# %% [markdown]
# 1) Choose an appropriate point and subtract that from all the data points. Here we would take 5. All the points shift towards left.<br>
# 2) After subtraction take square of all the points. The points represents a parabola.

# %% [markdown]
# Given 1D data points.
# ![image.png](attachment:image.png)

# %% [markdown]
# After subtraction
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# After squaring
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Now the parabolic representaion is linearly seperabl.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2D - 2 Dimension

# %% [markdown]
# To linearly seperate 2D data we use some mapping function.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Projecting back to 2D plane. We get a circle as the boundary of seperation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Types of Kernel

# %% [markdown]
# ![image.png](attachment:image.png)
