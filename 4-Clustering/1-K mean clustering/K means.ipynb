# %% [markdown]
# # K Mean Clustering

# %% [markdown]
# Consider a situation where we have 2 variables and the output is the datapoint. Now the question is how do we seperate these data points in different groups and how many groups ??

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### How does K mean algorithm works??

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here we can observer that one red point is in blue cluster and two blue points are in reg region. So we make th blue datapoints in red region and red and the red datapoint in blue region is made blue. This is called reassignment. Since we have done reassignment to the centroid also needs to be shifted and we go back to STEP 4 and then come to STEP 5 to check if no data point is out of its cluster. This process is repeated untill we get proper clusters. So this is an iterative process till the algorithm converges.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
