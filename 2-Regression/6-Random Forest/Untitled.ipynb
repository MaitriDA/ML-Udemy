# %% [markdown]
# ## Random Forest

# %% [markdown]
# Random Forest is a version of ensemble learning.<br>
# Ensemble learning is taking multiple algorithm or same algorithm multiple times to make something more powerful.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## STEP 1 - Data Pre processing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Position_Salaries.csv')
x=df.iloc[:,1:-1].values
y=df.iloc[:,-1].values

# %% [markdown]
# ## STEP 2 - Training the model on whole dataset

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(n_estimators=10,random_state=0)
rf.fit(x,y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
rf.predict([[6.5]])
# Out:
# array([167000.])

# %% [markdown]
# ## STEP 3 - Visualisation

# %%
x_grid=np.arange(min(x),max(x),0.01)
x_grid=x_grid.reshape((len(x_grid),1))
plt.scatter(x,y,color='red')
plt.plot(x_grid,rf.predict(x_grid),color='blue')
plt.title('Truth or Bluff (Random Forest Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
